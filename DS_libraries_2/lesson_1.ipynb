# %% [markdown]
# # Урок 1. Введение в задачу классификации. Постановка задачи и подготовка данных.

# %% [markdown]
# ### 1. Приведите по 2 примера, когда лучше максимизировать Precision, а когда Recall.

# %% [markdown]
# #### Precision
# - Модель, которая определяет по медецинским данным пригодность человека к проведению опасных для жизни работ.
# - Модель, которая помогает людям определять пригодность компании для инвестиций в нее.
#
# #### Recall
# - Модель, по совокупности данных определяющая начинающееся землетрясение.
# - Модель, определяющая подозрительное поведение человека в общественном месте.

# %% [markdown]
# ### 2. Почему мы используем F-меру, почему, например, нельзя просто взять среднее от Precision и Recall?

# %% [markdown]
# - F-мера дает возможность задать вес для полноты или для точности, если какой-то параметр более существенен.
# - Для максимизации F-меры необходимо существенно увеличивать оба параметра - полноту и точность, увеличение всего одного из параметров существенного изменения не даст.
